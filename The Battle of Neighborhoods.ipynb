# %% [markdown]
# <h1>Capstone Project - The Battle of Neighborhoods</h1>
# <p>The purpose of this Project is to explore better facilities around the future neighborhoods of New York and Toronto. The Data Analysis will help make a smart and efficient decision on selecting the best neighborhood via comparison from data analysis. People need to do lots of research for good housing prices and reputated schools for their children as well as better facilities like supermarkets, mall, restaurents,etc.
#     The Data analysis can give many ideas to someone like if someone is looking to open a restaurant, where he/she can open it and Similarly, if a contractor is trying to start their own business, where he/she can open an office.
# We will do a comparative analysis of the best neighborhoods based on the housing price, school location, supermarket location and type, and facilities around in order to find the best possible option(s).
# </p>
# <h1>Data Analysis</h1>
# <p>In order to data analysis we used data from various sources:</p>
# <p>(1) Postal codes of Canada (Wikipedia Page)</p>
# <p>(2) Geospatial Co-ordinates</p>
# <p>(3) Foursquare API(prime and major data source)</p>
# <p>(4) Various Python libraries for implementing k-means clustering algorithm(ex:Pandas, Folium, Matplotlib,etc.)</p>
